# %%
import pandas as pd
import numpy as np
import requests
import json
import csv
import time
import matplotlib.pyplot as plt
import gmaps

# %%
# Configure gmaps with API key

gkey = 'AIzaSyBy7utIDcTUJb02EAlU02aZHA3CoYqDWnc'
gmaps.configure(api_key = gkey)

# %%
#This is our source file with inspection data as of March 26, 2019
file = "nyc_pr_20k_plus_colorsprice.csv"
#Read csv file into nyc_inspect and list columns
nyc_pr1 = pd.read_csv(file)

nyc_pr1.head()
# Out:
#       CAMIS                             DBA       BORO BUILDING  \
# 0  30075445           MORRIS PARK BAKE SHOP      BRONX     1007
# 1  30112340                         WENDY'S   BROOKLYN      469
# 2  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 3  40356483              WILKEN'S FINE FOOD   BROOKLYN     7114
# 4  40356731     TASTE THE TROPICS ICE CREAM   BROOKLYN     1839
#
#              STREET  ZIPCODE       PHONE              CUISINE DESCRIPTION  \
# 0   MORRIS PARK AVE  10462.0  7188924968                           Bakery
# 1   FLATBUSH AVENUE  11225.0  7182875005                       Hamburgers
# 2  WEST   57 STREET  10019.0  2122452912                            Irish
# 3          AVENUE U  11234.0  7184443838                     Delicatessen
# 4   NOSTRAND AVENUE  11226.0  7188560821  Ice Cream, Gelato, Yogurt, Ices
#
#   INSPECTION_DATE                                           ACTION    ...      \
# ...

# %%
nyc_pr2 = nyc_pr1
nyc_pr2['Lat']=''
nyc_pr2['Lon']=''
nyc_pr2.head()
# Out:
#       CAMIS                             DBA       BORO BUILDING  \
# 0  30075445           MORRIS PARK BAKE SHOP      BRONX     1007
# 1  30112340                         WENDY'S   BROOKLYN      469
# 2  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 3  40356483              WILKEN'S FINE FOOD   BROOKLYN     7114
# 4  40356731     TASTE THE TROPICS ICE CREAM   BROOKLYN     1839
#
#              STREET  ZIPCODE       PHONE              CUISINE DESCRIPTION  \
# 0   MORRIS PARK AVE  10462.0  7188924968                           Bakery
# 1   FLATBUSH AVENUE  11225.0  7182875005                       Hamburgers
# 2  WEST   57 STREET  10019.0  2122452912                            Irish
# 3          AVENUE U  11234.0  7184443838                     Delicatessen
# 4   NOSTRAND AVENUE  11226.0  7188560821  Ice Cream, Gelato, Yogurt, Ices
#
#   INSPECTION_DATE                                           ACTION ...  \
# ...

# %%
#get lat and long and add to dataframe
call = 0
index = 0
for index, row in nyc_pr2.iterrows():
    call += 1
    if call % 100 == 0:
        print(call)
    try:
        address = nyc_pr2.loc[index,'BUILDING']
        address = address + (f" {nyc_pr2.loc[index,'STREET']}, New York City, New York")

        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(address, gkey)
        geo_data = requests.get(target_url).json()
       
        latx = geo_data["results"][0]["geometry"]["location"]["lat"]
        lngx = geo_data["results"][0]["geometry"]["location"]["lng"]
        nyc_pr2.loc[index,'Lat'] = latx
        nyc_pr2.loc[index,'Lon'] = lngx
    except:
        print(index)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 770
# 800
# 826
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2393
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5876
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 6954
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 8946
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9655
# 9700
# 9791
# 9800
# 9900
# 10000
# 10100
# 10200
# 10203
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11159
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# ...

# %%
nyc_pr2.head()
# Out:
#       CAMIS                             DBA       BORO BUILDING  \
# 0  30075445           MORRIS PARK BAKE SHOP      BRONX     1007
# 1  30112340                         WENDY'S   BROOKLYN      469
# 2  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 3  40356483              WILKEN'S FINE FOOD   BROOKLYN     7114
# 4  40356731     TASTE THE TROPICS ICE CREAM   BROOKLYN     1839
#
#              STREET  ZIPCODE       PHONE              CUISINE DESCRIPTION  \
# 0   MORRIS PARK AVE  10462.0  7188924968                           Bakery
# 1   FLATBUSH AVENUE  11225.0  7182875005                       Hamburgers
# 2  WEST   57 STREET  10019.0  2122452912                            Irish
# 3          AVENUE U  11234.0  7184443838                     Delicatessen
# 4   NOSTRAND AVENUE  11226.0  7188560821  Ice Cream, Gelato, Yogurt, Ices
#
#   INSPECTION_DATE                                           ACTION   ...     \
# ...

# %%
nyc_pr2.to_csv("nyc_pr2_20k_latlon_play.csv", index=False, header=True)

# %%
# if necessary restart file here to avoid having to remake the dataframe. 
file ="nyc_pr2_20k_latlon.csv"
nyc_pr2 = pd.read_csv(file)

# %%
nyc_pr2.query('Lat == ""')
# Out:
# Empty DataFrame
# Columns: [CAMIS, DBA, BORO, BUILDING, STREET, ZIPCODE, PHONE, CUISINE DESCRIPTION, INSPECTION_DATE, ACTION, VIOLATION CODE, VIOLATION DESCRIPTION, CRITICAL FLAG, SCORE, GRADE, GRADE DATE, RECORD DATE, INSPECTION_TYPE, Average Rating, Price, Review_Count, PriceQ, boro_color, Lat, Lon]
# Index: []
#
# [0 rows x 25 columns]

# %%
# remove rows that did not return positive data 
nyc_pr2a = nyc_pr2.drop([770,826,2393,5876,6954,8946,9655,9791,10203,11159,13311,13806])

# %%
nyc_pr2a.query('Lon == ""')
# Out:
# Empty DataFrame
# Columns: [CAMIS, DBA, BORO, BUILDING, STREET, ZIPCODE, PHONE, CUISINE DESCRIPTION, INSPECTION_DATE, ACTION, VIOLATION CODE, VIOLATION DESCRIPTION, CRITICAL FLAG, SCORE, GRADE, GRADE DATE, RECORD DATE, INSPECTION_TYPE, Average Rating, Price, Review_Count, PriceQ, boro_color, Lat, Lon]
# Index: []
#
# [0 rows x 25 columns]

# %%
nyc_pr2a.head(13800)
# Out:
#           CAMIS                              DBA           BORO BUILDING  \
# 0      30075445            MORRIS PARK BAKE SHOP          BRONX     1007
# 1      30112340                          WENDY'S       BROOKLYN      469
# 2      30191841   DJ REYNOLDS PUB AND RESTAURANT      MANHATTAN      351
# 3      40356483               WILKEN'S FINE FOOD       BROOKLYN     7114
# 4      40356731      TASTE THE TROPICS ICE CREAM       BROOKLYN     1839
# 5      40360076                 CARVEL ICE CREAM       BROOKLYN      203
# 6      40361322                 CARVEL ICE CREAM         QUEENS    26515
# 7      40361618                       SAL'S DELI         QUEENS    12908
# 8      40361998       STEVE CHU'S DELI & GROCERY         QUEENS     3406
# 9      40362098                HARRIET'S KITCHEN      MANHATTAN      502
# 10     40362264               P & S DELI GROCERY      MANHATTAN      730
# 11     40362274             ANGELIKA FILM CENTER      MANHATTAN       18
# ...

# %%
nyc_pr2a["Lat"].dtypes
# Out:
# dtype('O')

# %%
nyc_pr2a["Lon"].dtypes
# Out:
# dtype('O')

# %%
nyc_pr2a["Lat"] = pd.to_numeric(nyc_pr2a["Lat"], downcast='float')
nyc_pr2a["Lon"] = pd.to_numeric(nyc_pr2a["Lon"], downcast='float')

# %%
nyc_pr2a.head()
# Out:
#       CAMIS                             DBA       BORO BUILDING  \
# 0  30075445           MORRIS PARK BAKE SHOP      BRONX     1007
# 1  30112340                         WENDY'S   BROOKLYN      469
# 2  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 3  40356483              WILKEN'S FINE FOOD   BROOKLYN     7114
# 4  40356731     TASTE THE TROPICS ICE CREAM   BROOKLYN     1839
#
#              STREET  ZIPCODE       PHONE              CUISINE DESCRIPTION  \
# 0   MORRIS PARK AVE  10462.0  7188924968                           Bakery
# 1   FLATBUSH AVENUE  11225.0  7182875005                       Hamburgers
# 2  WEST   57 STREET  10019.0  2122452912                            Irish
# 3          AVENUE U  11234.0  7184443838                     Delicatessen
# 4   NOSTRAND AVENUE  11226.0  7188560821  Ice Cream, Gelato, Yogurt, Ices
#
#   INSPECTION_DATE                                           ACTION    ...      \
# ...

# %%
nyc_pr2a.to_csv("nyc_pr2a_20k.csv", index=False, header=True)

# %%
nyc_pr2a["Lon"].dtypes
# Out:
# dtype('float32')

# %%
nyc_pr2a["Lat"].dtypes
# Out:
# dtype('float32')

# %%
# remove columns we won't be using
nyc_pr3 = nyc_pr2a.drop(columns=['GRADE DATE', 'RECORD DATE', 'INSPECTION_DATE', 'INSPECTION_TYPE', 'CAMIS', 'ACTION','VIOLATION DESCRIPTION','CRITICAL FLAG','VIOLATION CODE'])
nyc_pr3.head(70)
# Out:
#                                DBA           BORO BUILDING  \
# 0            MORRIS PARK BAKE SHOP          BRONX     1007
# 1                          WENDY'S       BROOKLYN      469
# 2   DJ REYNOLDS PUB AND RESTAURANT      MANHATTAN      351
# 3               WILKEN'S FINE FOOD       BROOKLYN     7114
# 4      TASTE THE TROPICS ICE CREAM       BROOKLYN     1839
# 5                 CARVEL ICE CREAM       BROOKLYN      203
# 6                 CARVEL ICE CREAM         QUEENS    26515
# 7                       SAL'S DELI         QUEENS    12908
# 8       STEVE CHU'S DELI & GROCERY         QUEENS     3406
# 9                HARRIET'S KITCHEN      MANHATTAN      502
# 10              P & S DELI GROCERY      MANHATTAN      730
# 11            ANGELIKA FILM CENTER      MANHATTAN       18
# 12               HO MEI RESTAURANT         QUEENS    10305
# 13                THE COUNTRY CAFE      MANHATTAN       60
# 14                  DUNKIN' DONUTS       BROOKLYN       56
# ...

# %%
# find restaraunt with -1 Score (illogical value/data set error)
nyc_pr3.query('SCORE == "-1"')
# Out:
# Empty DataFrame
# Columns: [CAMIS, DBA, BORO, BUILDING, STREET, ZIPCODE, PHONE, CUISINE DESCRIPTION, INSPECTION_DATE, ACTION, VIOLATION CODE, VIOLATION DESCRIPTION, CRITICAL FLAG, SCORE, GRADE, GRADE DATE, RECORD DATE, INSPECTION_TYPE, Average Rating, Price, Review_Count, PriceQ, boro_color, Lat, Lon]
# Index: []
#
# [0 rows x 25 columns]

# %%
nyc_pr3 = nyc_pr3.drop([3505,7948])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-7cc82221c28c> in <module>
# ----> 1 nyc_pr3 = nyc_pr3.drop([3505,7948])
#       2
#
# /anaconda3/envs/python_data/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/envs/python_data/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
nyc_pr3.to_csv("nyc_pr3_20k.csv", index=False, header=True)

# %%
nyc_pr3['SCORE'].dtypes
# Out:
# dtype('float64')

# %%
nyc_pr3.reset_index(drop=True)
# Out:
#           CAMIS                              DBA           BORO BUILDING  \
# 0      30075445            MORRIS PARK BAKE SHOP          BRONX     1007
# 1      30112340                          WENDY'S       BROOKLYN      469
# 2      30191841   DJ REYNOLDS PUB AND RESTAURANT      MANHATTAN      351
# 3      40356483               WILKEN'S FINE FOOD       BROOKLYN     7114
# 4      40356731      TASTE THE TROPICS ICE CREAM       BROOKLYN     1839
# 5      40360076                 CARVEL ICE CREAM       BROOKLYN      203
# 6      40361322                 CARVEL ICE CREAM         QUEENS    26515
# 7      40361618                       SAL'S DELI         QUEENS    12908
# 8      40361998       STEVE CHU'S DELI & GROCERY         QUEENS     3406
# 9      40362098                HARRIET'S KITCHEN      MANHATTAN      502
# 10     40362264               P & S DELI GROCERY      MANHATTAN      730
# 11     40362274             ANGELIKA FILM CENTER      MANHATTAN       18
# ...

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = nyc_pr3[["Lat", "Lon"]]

# Convert Poverty Rate to float and store
# HINT: be sure to handle NaN values
h_score = nyc_pr3["SCORE"]

# %%
# # Create a dirty Heatmap layer
# fig = gmaps.figure()


# heat_layer = gmaps.heatmap_layer(locations, weights=(h_score)/50) 
                                 

# # Adjust heat_layer setting to help with heatmap dissipating on zoom
# heat_layer.dissipating = False

# heat_layer.max_intensity = 1
# heat_layer.point_radius = .001

# fig.add_layer(heat_layer)



# fig

# %%
nyc_pr3.head()

#test.head()
# Out:
#       CAMIS                             DBA       BORO BUILDING  \
# 0  30075445           MORRIS PARK BAKE SHOP      BRONX     1007
# 1  30112340                         WENDY'S   BROOKLYN      469
# 2  30191841  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351
# 3  40356483              WILKEN'S FINE FOOD   BROOKLYN     7114
# 4  40356731     TASTE THE TROPICS ICE CREAM   BROOKLYN     1839
#
#              STREET  ZIPCODE       PHONE              CUISINE DESCRIPTION  \
# 0   MORRIS PARK AVE  10462.0  7188924968                           Bakery
# 1   FLATBUSH AVENUE  11225.0  7182875005                       Hamburgers
# 2  WEST   57 STREET  10019.0  2122452912                            Irish
# 3          AVENUE U  11234.0  7184443838                     Delicatessen
# 4   NOSTRAND AVENUE  11226.0  7188560821  Ice Cream, Gelato, Yogurt, Ices
#
#   INSPECTION_DATE                                           ACTION    ...      \
# ...

# %%
# Create a dirty Heatmap layer
fig = gmaps.figure()


heat_layer = gmaps.heatmap_layer(locations, weights=(h_score*h_score)/10) 
                                 

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False

heat_layer.max_intensity = 2
heat_layer.point_radius = .00004

fig.add_layer(heat_layer)



fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
nyc_pr3.query('DBA == "KARMA"')
# Out:
#          CAMIS    DBA       BORO BUILDING    STREET  ZIPCODE       PHONE  \
# 1541  40720587  KARMA  MANHATTAN       51  1 AVENUE  10003.0  2126773160
#
#      CUISINE DESCRIPTION INSPECTION_DATE  \
# 1541            American      2018-12-17
#
#                                                ACTION    ...      GRADE DATE  \
# 1541  Violations were cited in the following area(s).    ...      12/17/2018
#
#      RECORD DATE                   INSPECTION_TYPE  Average Rating Price  \
# 1541  03/20/2019  Cycle Inspection / Re-inspection             2.5    $$
#
#      Review_Count PriceQ boro_color        Lat        Lon
# 1541          314      2          c  40.724934 -73.987663
#
# [1 rows x 25 columns]

# %%
nyc_pr3.query('DBA == "ELEVEN B"')
