# %%
import pandas as pd
import numpy as np
import requests
import json
import csv
import time
import matplotlib.pyplot as plt
import gmaps

# %%
# Configure gmaps with API key

gkey = 'AIzaSyBy7utIDcTUJb02EAlU02aZHA3CoYqDWnc'
gmaps.configure(api_key = gkey)

# %%
#$$$$$$$$$$
file = "nyc_pr3_20k.csv"
nyc_pr3 = pd.read_csv(file)

# %%
nyc_pr3.head(3506)
# Out:
#          CAMIS                                    DBA           BORO BUILDING  \
# 0     30075445                  MORRIS PARK BAKE SHOP          BRONX     1007
# 1     30112340                                WENDY'S       BROOKLYN      469
# 2     30191841         DJ REYNOLDS PUB AND RESTAURANT      MANHATTAN      351
# 3     40356483                     WILKEN'S FINE FOOD       BROOKLYN     7114
# 4     40356731            TASTE THE TROPICS ICE CREAM       BROOKLYN     1839
# 5     40360076                       CARVEL ICE CREAM       BROOKLYN      203
# 6     40361322                       CARVEL ICE CREAM         QUEENS    26515
# 7     40361618                             SAL'S DELI         QUEENS    12908
# 8     40361998             STEVE CHU'S DELI & GROCERY         QUEENS     3406
# 9     40362098                      HARRIET'S KITCHEN      MANHATTAN      502
# 10    40362264                     P & S DELI GROCERY      MANHATTAN      730
# ...

# %%
nyc_pr3a = nyc_pr3.drop(columns=['GRADE DATE', 'RECORD DATE', 'INSPECTION_DATE', 'INSPECTION_TYPE', 'CAMIS', 'ACTION','VIOLATION DESCRIPTION','CRITICAL FLAG','VIOLATION CODE'])
nyc_pr3a.head()
# Out:
#                               DBA       BORO BUILDING            STREET  \
# 0           MORRIS PARK BAKE SHOP      BRONX     1007   MORRIS PARK AVE
# 1                         WENDY'S   BROOKLYN      469   FLATBUSH AVENUE
# 2  DJ REYNOLDS PUB AND RESTAURANT  MANHATTAN      351  WEST   57 STREET
# 3              WILKEN'S FINE FOOD   BROOKLYN     7114          AVENUE U
# 4     TASTE THE TROPICS ICE CREAM   BROOKLYN     1839   NOSTRAND AVENUE
#
#    ZIPCODE       PHONE              CUISINE DESCRIPTION  SCORE GRADE  \
# 0  10462.0  7188924968                           Bakery    5.0     A
# 1  11225.0  7182875005                       Hamburgers   13.0     A
# 2  10019.0  2122452912                            Irish   12.0     A
# 3  11234.0  7184443838                     Delicatessen   13.0     A
# 4  11226.0  7188560821  Ice Cream, Gelato, Yogurt, Ices   13.0     A
#
#    Average Rating Price  Review_Count  PriceQ boro_color        Lat       Lon
# ...

# %%
nyc_pr3.query('SCORE == "-1"')
# Out:
# Empty DataFrame
# Columns: [CAMIS, DBA, BORO, BUILDING, STREET, ZIPCODE, PHONE, CUISINE DESCRIPTION, INSPECTION_DATE, ACTION, VIOLATION CODE, VIOLATION DESCRIPTION, CRITICAL FLAG, SCORE, GRADE, GRADE DATE, RECORD DATE, INSPECTION_TYPE, Average Rating, Price, Review_Count, PriceQ, boro_color, Lat, Lon]
# Index: []
#
# [0 rows x 25 columns]

# %%
nyc_pr3["Lat"].dtypes
# Out:
# dtype('float64')

# %%
nyc_pr3["Lon"].dtypes
# Out:
# dtype('float64')

# %%
nyc_pr3['SCORE'].dtypes
# Out:
# dtype('float64')

# %%
nyc_pr3.reset_index(drop=True)
# Out:
#           CAMIS                              DBA           BORO BUILDING  \
# 0      30075445            MORRIS PARK BAKE SHOP          BRONX     1007
# 1      30112340                          WENDY'S       BROOKLYN      469
# 2      30191841   DJ REYNOLDS PUB AND RESTAURANT      MANHATTAN      351
# 3      40356483               WILKEN'S FINE FOOD       BROOKLYN     7114
# 4      40356731      TASTE THE TROPICS ICE CREAM       BROOKLYN     1839
# 5      40360076                 CARVEL ICE CREAM       BROOKLYN      203
# 6      40361322                 CARVEL ICE CREAM         QUEENS    26515
# 7      40361618                       SAL'S DELI         QUEENS    12908
# 8      40361998       STEVE CHU'S DELI & GROCERY         QUEENS     3406
# 9      40362098                HARRIET'S KITCHEN      MANHATTAN      502
# 10     40362264               P & S DELI GROCERY      MANHATTAN      730
# 11     40362274             ANGELIKA FILM CENTER      MANHATTAN       18
# ...

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = nyc_pr3[["Lat", "Lon"]]

# Convert Poverty Rate to float and store
# HINT: be sure to handle NaN values
h_score = nyc_pr3["SCORE"]

# Create a dirty Heatmap layer
fig = gmaps.figure()


heat_layer = gmaps.heatmap_layer(locations, weights=(h_score*h_score)/10) 
                                 

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False

heat_layer.max_intensity = 2
heat_layer.point_radius = .00004

fig.add_layer(heat_layer)



fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
name ='TIMNA'
nyc_find = nyc_pr3[nyc_pr3['DBA'].str.contains(name)]

nyc_find
# Out:
#           CAMIS    DBA       BORO BUILDING          STREET  ZIPCODE  \
# 10794  50034177  TIMNA  MANHATTAN      109  SAINT MARKS PL  10009.0
#
#             PHONE CUISINE DESCRIPTION INSPECTION_DATE  \
# 10794  6469645181       Mediterranean      2018-10-26
#
#                                                 ACTION    ...     GRADE DATE  \
# 10794  Violations were cited in the following area(s).    ...     10/26/2018
#
#       RECORD DATE                   INSPECTION_TYPE  Average Rating Price  \
# 10794  03/20/2019  Cycle Inspection / Re-inspection             4.5   $$$
#
#       Review_Count PriceQ boro_color        Lat       Lon
# 10794          315      3          c  40.727207 -73.98389
#
# [1 rows x 25 columns]

# %%
# make a heat map by Price
# Store 'Lat' and 'Lng' into  locations 
locations = nyc_pr3[["Lat", "Lon"]]

# Convert Poverty Rate to float and store
# HINT: be sure to handle NaN values
h_score = nyc_pr3["PriceQ"]


fig = gmaps.figure()


heat_layer = gmaps.heatmap_layer(locations, weights=(h_score*h_score))

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False

heat_layer.max_intensity = 1
heat_layer.point_radius = .00005

fig.add_layer(heat_layer)



fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#nyc_pr3.query("CITY GOURMET DELI & CAFE" in )
name ='TIMNA'
nyc_find = nyc_pr3[nyc_pr3['DBA'].str.contains(name)]

nyc_find
# Out:
#           CAMIS    DBA       BORO BUILDING          STREET  ZIPCODE  \
# 10794  50034177  TIMNA  MANHATTAN      109  SAINT MARKS PL  10009.0
#
#             PHONE CUISINE DESCRIPTION INSPECTION_DATE  \
# 10794  6469645181       Mediterranean      2018-10-26
#
#                                                 ACTION    ...     GRADE DATE  \
# 10794  Violations were cited in the following area(s).    ...     10/26/2018
#
#       RECORD DATE                   INSPECTION_TYPE  Average Rating Price  \
# 10794  03/20/2019  Cycle Inspection / Re-inspection             4.5   $$$
#
#       Review_Count PriceQ boro_color        Lat       Lon
# 10794          315      3          c  40.727207 -73.98389
#
# [1 rows x 25 columns]
